# %% [markdown]
# # Python Decision Tree Notebook
#
# This notebook follows documentation from http://scikit-learn.org/stable/modules/tree.html
#
# We are using an empty server. It has no code on it for us to use! First thing we need to do is install some packages:

# %%
import pandas as pd

# %%
data = pd.read_csv("HR_clean.csv")
data.head()
# Out:
#     department  region      termination_date bracket_salary 1  salary  \
# 0    technical      US  2015-06-27T00:00:00Z              low   52000
# 1  product_mng  Europe  2017-02-24T00:00:00Z              low   36000
# 2        sales  Canada  2008-12-06T00:00:00Z           medium   77000
# 3      support      US  2015-11-22T00:00:00Z           medium   70000
# 4    technical      US  2009-03-29T00:00:00Z           medium   76000
#
#    satisfaction_level  last_evaluation  number_project  average_monthly_hours  \
# 0                0.82             0.63               4                    232
# 1                0.72             0.79               4                    154
# 2                0.71             0.88               3                    140
# 3                0.53             0.75               4                    239
# 4                0.49             0.49               2                    245
#
#    time_spend_company  work_accident  promotion_last_5years  resigned
# ...

# %%
# %matplotlib notebook
plot1 = data.plot.scatter(x = 'last_evaluation', y = 'satisfaction_level', c = 'resigned', colormap = 'Accent')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
Y = data["resigned"]
X = data.iloc[:,4:-1]

# %%
from sklearn import tree
clf = tree.DecisionTreeClassifier()
clf = clf.fit(X, Y)

# %%
clf
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')

# %%
import graphviz 
dot_data = tree.export_graphviz(clf, out_file=None) 
graph = graphviz.Source(dot_data) 
graph.render("data")
# Out:
# 'data.pdf'

# %%
dot_data = tree.export_graphviz(clf, out_file=None, 
                         feature_names=data.feature_names,  
                         class_names=data.target_names,  
                         filled=True, rounded=True,  
                         special_characters=True)  
graph = graphviz.Source(dot_data)  
graph
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-10-18e6470b9ebc> in <module>()
#       1 dot_data = tree.export_graphviz(clf, out_file=None,
# ----> 2                          feature_names=data.feature_names,
#       3                          class_names=data.target_names,
#       4                          filled=True, rounded=True,
#       5                          special_characters=True)
#
# /usr/local/lib/python3.7/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    4374             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    4375                 return self[name]
# -> 4376             return object.__getattribute__(self, name)
#    4377
#    4378     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'feature_names'
